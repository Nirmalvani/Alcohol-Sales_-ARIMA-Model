# %% [markdown]
# # Time series Project

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Alcohol_Sales.csv',index_col=0,parse_dates=True)

# %%
df.head(3)
# Out:
#             S4248SM144NCEN
# DATE
# 1992-01-01            3459
# 1992-02-01            3458
# 1992-03-01            4002

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 325 entries, 1992-01-01 to 2019-01-01
# Data columns (total 1 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   S4248SM144NCEN  325 non-null    int64
# dtypes: int64(1)
# memory usage: 5.1 KB

# %%
df.rename(columns={'S4248SM144NCEN':'Sales'},inplace=True)

# %%
df
# Out:
#             Sales
# DATE
# 1992-01-01   3459
# 1992-02-01   3458
# 1992-03-01   4002
# 1992-04-01   4564
# 1992-05-01   4221
# ...           ...
# 2018-09-01  12396
# 2018-10-01  13914
# 2018-11-01  14174
# 2018-12-01  15504
# 2019-01-01  10718
#
# [325 rows x 1 columns]

# %% [markdown]
# #### Let's see the stationarity of the Sales

# %%
plt.plot(df)

# %%
# We can see a trend here. Let's see it mathematically.

# %%
from statsmodels.tsa.stattools import adfuller

# %%
# Function to check stationarity mathematically
def ad_test(dataset):
    a = adfuller(dataset,autolag="AIC")
    print(f"1. ADF : {a[0]}")
    print(f"2. P-value : {a[1]}")    
    print(f"3. Num of lags : {a[2]}")
    print(f"4. Number of observation used for ADF regression and Critical values calculation : {a[3]}")
    print(f"5. Critical values : ")
    for key,val in a[4].items():
        print("\t",key,":",val)

# %%
ad_test(df['Sales'])
# Out:
# 1. ADF : 2.0374047259136914
# 2. P-value : 0.9987196267088919
# 3. Num of lags : 14
# 4. Number of observation used for ADF regression and Critical values calculation : 310
# 5. Critical values :
# 	 1% : -3.451621854687657
# 	 5% : -2.870908950689806
# 	 10% : -2.571761810613944

# %% [markdown]
# **P- value >0.05** so the mathematically as well the data is non stationary.

# %% [markdown]
# Lets make it stationary

# %%
df['Sales_difference'] = df['Sales'] - df['Sales'].shift(1)

# %%
ad_test(df['Sales_difference'].dropna()) # Now it is stationry data.
# Out:
# 1. ADF : -4.365959619246061
# 2. P-value : 0.00034082849211699125
# 3. Num of lags : 13
# 4. Number of observation used for ADF regression and Critical values calculation : 310
# 5. Critical values :
# 	 1% : -3.451621854687657
# 	 5% : -2.870908950689806
# 	 10% : -2.571761810613944

# %%
import matplotlib.pyplot as plt
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# Plot the ACF
plt.figure(figsize=(10, 5))
plot_acf(df['Sales_difference'].dropna(), lags=100, ax=plt.gca())
plt.title('ACF Plot')
plt.show()

# %%
# Plot the PACF
plt.figure(figsize=(10, 5))
plot_pacf(df['Sales_difference'].dropna(), lags=60, ax=plt.gca())
plt.title('PACF Plot')
plt.show()

# %%
# Assuming `sales_stationary` is your stationary time series data
train_size = int(len(df['Sales_difference']) * 0.8)  # Use 80% of data for training
train = df['Sales_difference'][:train_size]
test = df['Sales_difference'][train_size:]

# %%
from statsmodels.tsa.arima.model import ARIMA

# Assuming 'data' is your stationary time series
model = ARIMA(train, order=(96, 1, 24))  # Replace p, d, q with appropriate values
model_fit = model.fit()
# Out:
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\base\tsa_model.py:473: ValueWarning: No frequency information was provided, so inferred frequency MS will be used.
#   self._init_dates(dates, freq)
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:966: UserWarning: Non-stationary starting autoregressive parameters found. Using zeros as starting parameters.
#   warn('Non-stationary starting autoregressive parameters'
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\tsa\statespace\sarimax.py:978: UserWarning: Non-invertible starting MA parameters found. Using zeros as starting parameters.
#   warn('Non-invertible starting MA parameters found.'
# C:\Users\Admin\anaconda3\Lib\site-packages\statsmodels\base\model.py:607: ConvergenceWarning: Maximum Likelihood optimization failed to converge. Check mle_retvals
#   warnings.warn("Maximum Likelihood optimization failed to "

# %%
# Print model summary
print(model_fit.summary())
# Out:
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:       Sales_difference   No. Observations:                  260
# Model:               ARIMA(96, 1, 24)   Log Likelihood               -1795.481
# Date:                Thu, 29 Aug 2024   AIC                           3832.961
# Time:                        13:40:04   BIC                           4263.337
# Sample:                    01-01-1992   HQIC                          4005.998
#                          - 08-01-2013
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1         -0
# ar.L91        -0.4981      0.377     -1.321      0.187      -1.237       0.241
# ar.L92        -0.2316      0.468     -0.495      0.620      -1.148       0.685
# ar.L93        -0.1885      0.461     -0.408      0.683      -1.093       0.716
# ar.L94        -0.1469      0.397     -0.370      0.712      -0.925       0.632
# ar.L95        -0.0095      0.356     -0.027      0.979      -0.707       0.688
# ar.L96        -0.0870      0.401     -0.217      0.828      -0.873       0.699
# ma.L1         -0.9942      1.345     -0.739      0.460      -3.631       1.643
# ma.L2          0.0190      2.557      0.007      0.994      -4.992       5.030
# ma.L3          0.2895      1.597      0.181      0.856      -2.840       3.419
# ma.L4         -0.5049      1.687     -0.299      0.765      -3.812       2.802
# ma.L5          0.4101      2.458      0.167      0.867      -4.407       5.227
# ma.L6         -0.1165      1.627     -0.072      0.943      -3.305       3.072
# ma.L7         -0.0271      0.902     -0.030      0.976      -1.795       1.741
# ma.L8         -0.0569      1.072     -0.053      0.958      -2.158       2.044
# ma.L9          0.0782      0.768      0.102      0.919      -1.427       1.584
# ma.L10        -0.2489      0.519     -0.480      0.631      -1.265       0.767
# ma.L11        -0.1416      0.627     -0.226      0.822      -1.371       1.088
# ma.L12         1.0658      0.829      1.286      0.198      -0.559       2.690
# ma.L13        -0.7484      1.462     -0.512      0.609      -3.613       2.117
# ma.L14         0.2791      2.377      0.117      0.907      -4.379       4.938
# ma.L15         0.0680      1.439      0.047      0.962      -2.753       2.889
# ma.L16        -0.4585      1.041     -0.440      0.660      -2.499       1.582
# ma.L17         0.2223      1.754      0.127      0.899      -3.215       3.660
# ma.L18        -0.0801      1.355     -0.059      0.953      -2.736       2.575
# ma.L19         0.1402      0.813      0.172      0.863      -1.453       1.734
# ma.L20         0.0767      0.648      0.118      0.906      -1.193       1.347
# ma.L21        -0.2189      0.593     -0.369      0.712      -1.382       0.944
# ma.L22        -0.0260      0.880     -0.030      0.976      -1.751       1.699
# ma.L23        -0.1763      0.787     -0.224      0.823      -1.719       1.366
# ma.L24         0.3108      0.474      0.656      0.512      -0.618       1.240
# sigma2      1.982e+04   5165.835      3.837      0.000    9698.121    2.99e+04
# ===================================================================================
# Ljung-Box (L1) (Q):                   1.53   Jarque-Bera (JB):                 0.36
# Prob(Q):                              0.22   Prob(JB):                         0.84
# Heteroskedasticity (H):               3.31   Skew:                             0.00
# Prob(H) (two-sided):                  0.00   Kurtosis:                         3.18
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
# Forecast the next points corresponding to the length of the test data
predictions = model_fit.forecast(steps=len(test))

plt.figure(figsize=(10, 6))
plt.plot(test, label="Actual (Test Data)")
plt.plot(predictions, label="Predicted (Forecast)", color='red')
plt.title("Actual vs Predicted")
plt.legend()
plt.show()

# %%
# Assuming you have the last value before differencing
last_original_value = df['Sales'].iloc[train_size - 1]  # The last value before the test set

# Invert the differencing for predictions
predictions_original_scale = predictions.cumsum() + last_original_value

# You can then plot `predictions_original_scale` against the original `sales` data

# %%
plt.plot(df['Sales'], label="Actual (Test Data)")
plt.plot(predictions_original_scale, label="Predicted (Forecast)", color='red')

# %%
mape = np.mean(np.abs((test - predictions) / test)) * 100
print(f'Mean Absolute Percentage Error (MAPE): {mape}%')
# Out:
# Mean Absolute Percentage Error (MAPE): 90.20434243703781%

# %% [markdown]
# ## We got 90% accuracy. And visually it is is following the following the trend.
